# %% [markdown]
# # Instructor Do: Getting Data for Sentiment Analysis

# %%
# Initial imports
import os
import pandas as pd
from newsapi import NewsApiClient # pip install newsapi-python 
from dotenv import load_dotenv
load_dotenv('JLW.env')
# Out:
# True

# %%
# Reading the News API key enviroment variable
api_key = os.getenv("news_api")

# %%
type(api_key)
# Out:
# str

# %%
# Create a newsapi client
newsapi = NewsApiClient(api_key=api_key)

# %%
# Fetch top news articles about oil
oil_headlines = newsapi.get_top_headlines(q="oil") # q="tesla", language="en", country="us"
oil_headlines
# Out:
# {'status': 'ok',
#  'totalResults': 2,
#  'articles': [{'source': {'id': 'news24', 'name': 'News24'},
#    'author': 'Kyle Cowan',
#    'title': "THE ESKOM FILES | De Ruyter: Econ Oil's Mlonzi admitted to acting 'improperly, if not corruptly' - News24",
#    'description': "Econ Oil director Nothemba Mlonzi has admitted to acting 'improperly, if not corruptly' in attempts to allegedly influence the awarding of a five-year multibillion-rand fuel oil supply tender, according to affidavits filed by Eskom CEO Andre de Ruyter in cour…",
#    'url': 'https://www.news24.com/news24/southafrica/investigations/eskomfiles/the-eskom-files-de-ruyter-econ-oils-mlonzi-admitted-to-acting-improperly-if-not-corruptly-20210605',
#    'urlToImage': 'https://cdn.24.co.za/files/Cms/General/d/11239/5274bb1869e84bc480033c1869fd317c.jpg',
#    'publishedAt': '2021-06-05T04:33:15Z',
#    'content': 'The managing director of Econ Oil, Nothemba Mlonzi, has admitted in court papers to acting "improperly, if not corruptly" in interfering with the award of a multibillion-rand fuel oil tender, accordi… [+407 chars]'},
#   {'source': {'id': None, 'name': 'CNBC'},
#    'author': 'Abigail Ng',
#    'title': 'Goldman says a nuclear deal with Iran could send oil prices higher. Not everyone agrees - CNBC',
#    'description': 'A deal between the U.S. and Iran could be bullish for oil prices despite an increase in supply, according to Damien Courvalin of Goldman Sachs.',
#    'url': 'https://www.cnbc.com/2021/06/04/investing-in-oil-what-iran-nuclear-deal-means-for-energy-markets.html',
#    'urlToImage': 'https://image.cnbcfm.com/api/v1/image/106887107-1621848473764-gettyimages-1232635142-AA_02052021_337185.jpeg?v=1622691184',
#    'publishedAt': '2021-06-04T04:07:17Z',
#    'content': 'Official cars are seen outside Grand Hotel Wien after a session of meeting of the Joint Comprehensive Plan of Action (JCPOA) on "Iran nuclear deal talks" in Vienna, Austria on May 01, 2021.\r\nA nuclea… [+4918 chars]'}]}

# %%
# Print total articles
print(f"Total articles about oil: {oil_headlines['totalResults']}")

# Show sample article
oil_headlines["articles"][0]
# Out:
# Total articles about oil: 3
# {'source': {'id': None, 'name': 'Phys.Org'},
#  'author': 'Jessica Colarossi',
#  'title': 'Why scientists want to solve an underground mystery about where microbes live - Phys.org',
#  'description': "Though it might seem inanimate, the soil under our feet is very much alive. It's filled with countless microorganisms actively breaking down organic matter, like fallen leaves and plants, and performing a host of other functions that maintain the natural bala…",
#  'url': 'https://phys.org/news/2021-06-scientists-underground-mystery-microbes.html',
#  'urlToImage': 'https://scx2.b-cdn.net/gfx/news/hires/2021/why-scientists-want-to-2.jpg',
#  'publishedAt': '2021-06-04T21:19:09Z',
#  'content': "Though it might seem inanimate, the soil under our feet is very much alive. It's filled with countless microorganisms actively breaking down organic matter, like fallen leaves and plants, and perform… [+6108 chars]"}

# %%
# Transform the response dictionary to a DataFrame
oil_df = pd.DataFrame.from_dict(oil_headlines["articles"])

oil_df.head()
# Out:
#                                   source             author  \
# 0       {'id': None, 'name': 'Phys.Org'}  Jessica Colarossi
# 1  {'id': None, 'name': 'Science Daily'}               None
# 2            {'id': None, 'name': 'CNA'}                CNA
#
#                                                title  \
# 0  Why scientists want to solve an underground my...
# 1  A new water treatment technology could also he...
# 2  International experts deployed to contain pote...
#
#                                          description  \
# 0  Though it might seem inanimate, the soil under...
# 1  A team created a catalyst from molybdenum fert...
# 2  Foreign experts have been deployed to help Sri...
#
#                                                  url  \
# 0  https://phys.org/news/2021-06-scientists-under...
# 1  https://www.sciencedaily.com/releases/2021/06/...
# 2  https://www.channelnewsasia.com/news/asia/inte...
#
#                                           urlToImage           publishedAt  \
# 0  https://scx2.b-cdn.net/gfx/news/hires/2021/why...  2021-06-04T21:19:09Z
# 1  https://www.sciencedaily.com/images/scidaily-i...  2021-06-04T20:35:11Z
# 2  https://cna-sg-res.cloudinary.com/image/upload...  2021-06-04T05:40:30Z
#
#                                              content
# 0  Though it might seem inanimate, the soil under...
# 1  A team led by UC Riverside engineers has devel...
# 2  COLOMBO: Foreign experts have been deployed to...

# %%
# Fetch all the news about Facebook Libra
libra_headlines = newsapi.get_everything(
    q="facebook libra", language="en", sort_by="relevancy"
)

# Print total articles
print(f"Total articles about Facebook Libra: {libra_headlines['totalResults']}")

# Show sample article
libra_headlines["articles"][0]
# Out:
# Total articles about Facebook Libra: 101
# {'source': {'id': 'engadget', 'name': 'Engadget'},
#  'author': 'https://www.engadget.com/about/editors/mariella-moon',
#  'title': "Facebook's Diem Association shifts its focus to the US",
#  'description': "Diem has withdrawn its application for a Swiss payment license from Switzerland's FINMA financial regulator..",
#  'url': 'https://www.engadget.com/facebook-diem-association-us-111008891.html',
#  'urlToImage': 'https://s.yimg.com/os/creatr-images/2019-10/2e15b870-e49b-11e9-97df-0bff4ac4372f',
#  'publishedAt': '2021-05-13T11:20:08Z',
#  'content': "The Facebook-backed Diem Association has revealed its plans to launch a stablecoin backed by the US dollar as it shifts its focus to the United States. Formerly known as Facebook's Libra Association,… [+1597 chars]"}

# %%
# Transform the response dictionary to a DataFrame
libra_df = pd.DataFrame.from_dict(libra_headlines["articles"])

libra_df.head()
# Out:
#           author                                            content  \
# 0  Romain Dillet  When Facebook unveiledLibra a few days ago, th...
# 1   Nick Douglas  On Tuesday Facebook announced Libra, a cryptoc...
# 2  Josh Constine  The $10 million entry fee to join the Facebook...
# 3     Jon Fingas  He added that Facebook is treating Libra as a ...
# 4     Steve Dent  "We write to request that Facebook and its par...
#
#                                          description           publishedAt  \
# 0  When Facebook unveiled Libra a few days ago, t...  2019-06-26T17:26:16Z
# 1  On Tuesday Facebook announced Libra, a cryptoc...  2019-06-19T13:49:00Z
# 2  The $10 million entry fee to join the Facebook...  2019-07-03T19:29:54Z
# 3  Facebook is determined to reassure officials t...  2019-07-15T17:14:00Z
# 4  US lawmakers have asked Facebook to "immediate...  2019-07-03T09:31:00Z
#
#                                        source  \
# 0  {'id': 'techcrunch', 'name': 'TechCrunch'}
# 1      {'id': None, 'name': 'Lifehacker.com'}
# 2  {'id': 'techcrunch', 'name': 'TechCrunch'}
# 3      {'id': 'engadget', 'name': 'Engadget'}
# 4      {'id': 'engadget', 'name': 'Engadget'}
#
#                                                title  \
# 0  What is the Libra Association going to do, rea...
# 1  Facebook's New Libra Coin: How Does It Work, a...
# 2  We still don’t know how much of Libra Facebook...
# 3  Facebook won't make Libra available until regu...
# 4  US lawmakers tell Facebook to halt the launch ...
#
#                                                  url  \
# 0  http://techcrunch.com/2019/06/26/what-is-the-l...
# 1  https://lifehacker.com/facebooks-new-libra-coi...
# 2  http://techcrunch.com/2019/07/03/facebook-libr...
# 3  https://www.engadget.com/2019/07/15/facebook-t...
# 4  https://www.engadget.com/2019/07/03/us-lawmake...
#
#                                           urlToImage
# 0  https://techcrunch.com/wp-content/uploads/2019...
# 1  https://i.kinja-img.com/gawker-media/image/upl...
# 2  https://techcrunch.com/wp-content/uploads/2019...
# 3  https://o.aolcdn.com/images/dims?thumbnail=120...
# 4  https://o.aolcdn.com/images/dims?thumbnail=120...
