# %%
from bit import wif_to_key
key = wif_to_key("cQ9GFdiHmRGVYi5Pym3ndA2omGQR2hWUy6rxAFiHVfWHYDtnjZb2")

# %%
key.get_balance("btc")
# Out:
# '0.00028992'

# %%
key.balance_as("gbp")
# Out:
# '8.21'

# %%
key.get_transactions()
# Out:
# ['9d59b0037662dffd4a7de17072ce21aa9e6cd1a9a3ecaaf0959c44c1e5efaf13',
#  'af8355d1a85b84fd371f81b36a92eabfc86b5c4a49741d2f02af455dc41df67d',
#  '2bc98f7f20b569e6d959c809da70828ee964697923f7f693cb80cb736d14b762',
#  'd84ff64cc674b7c8e1a819642cb3f3d1bcbe8a3bf8e5a2250eb993f78960391c',
#  '1a382234653e5631c3571a718dc7331042e4ad50e1cc5cf652fa96d348fef613',
#  '44cf7be3da770379bd7a39cb10240e6fecfd60bbc70593b13287d39481db8f1e',
#  'eb25edcd9f114e0ab40a74ceea8f0fb63a4f618b0f09a813e3e32299e9f43fee',
#  'a1c81466626f16cf8e12de556b2513a3b4f7bb09fa925355d472ae3945b5a784',
#  'beefe4a85d96dc05ff3d3709722c9d36ce84871cd47ab8749c3edd4a3d530f03']

# %%
key.get_unspents()
# Out:
# [Unspent(amount=28992, confirmations=15, script='76a9147e926a572b081168f49aa05ce14e3ebc972912d988ac', txid='9d59b0037662dffd4a7de17072ce21aa9e6cd1a9a3ecaaf0959c44c1e5efaf13', txindex=7, segwit=False, sequence=4294967295)]

# %%
txn_id = key.send(address1)

if(txn_id is cleared)
    key.send(address2)
