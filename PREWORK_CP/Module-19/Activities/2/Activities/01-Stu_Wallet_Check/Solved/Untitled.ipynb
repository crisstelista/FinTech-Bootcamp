# %%
from bit import wif_to_key

# %%
key = wif_to_key("cQ9GFdiHmRGVYi5Pym3ndA2omGQR2hWUy6rxAFiHVfWHYDtnjZb2")

# %%
key.get_balance("btc")
# Out:
# '0.00028992'

# %%
key.get_balance("usd")
# Out:
# '11.33'

# %%
key.address
# Out:
# 'ms4CqLw5Gz1z18ESxy4KXcgn5sWYfxnhzx'

# %%
addresses = ["mtdxAwV3yJYxctdW1f4hMDc5fC8o1VT3HN", 
            "mpEdwvBFa8czpVqf6YsHmZRc1KZkeqa8C4", 'mtdxAwV3yJYxctdW1f4hMDc5fC8o1VT3HN', 
             'mtP2SkuBdERsp8RT7Lo2AwrzS5ybsP1vvZ','mwjuRJAutR5pPuGXS3RevQcaoR3VXpyzyZ',
             'n4Z2MUUCfQtqaZ3AgEZKqt8DgEFv58Tier', 'mmp4evd9vuUeW2bmcPrmEmACdwyovfMTrJ']

outputs = []

for address in addresses:
    outputs.append((address, 0.00001, "btc"))

print(key.send(outputs))
# Out:
# 9d59b0037662dffd4a7de17072ce21aa9e6cd1a9a3ecaaf0959c44c1e5efaf13

# %%
ouputs = [('n4Z2MUUCfQtqaZ3AgEZKqt8DgEFv58Tier', 1000, "btc")]
key.send(outputs)
# Out:
# ---------------------------------------------------------------------------
# InsufficientFunds                         Traceback (most recent call last)
# <ipython-input-8-cc75e57f24fd> in <module>
#       1 ouputs = [('n4Z2MUUCfQtqaZ3AgEZKqt8DgEFv58Tier', 1000, "btc")]
# ----> 2 key.send(outputs)
#
# ~/anaconda3/envs/finance/lib/python3.6/site-packages/bit/wallet.py in send(self, outputs, fee, absolute_fee, leftover, combine, message, unspents, message_is_hex, replace_by_fee)
#     779             unspents=unspents,
#     780             message_is_hex=message_is_hex,
# --> 781             replace_by_fee=replace_by_fee
#     782         )
#     783
#
# ~/anaconda3/envs/finance/lib/python3.6/site-packages/bit/wallet.py in create_transaction(self, outputs, fee, absolute_fee, leftover, combine, message, unspents, message_is_hex, replace_by_fee)
#     716             version=self.version,
#     717             message_is_hex=message_is_hex,
# ...
