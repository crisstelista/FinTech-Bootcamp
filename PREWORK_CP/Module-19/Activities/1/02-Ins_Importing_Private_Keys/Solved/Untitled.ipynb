# %%
import os
from web3 import Web3
from dotenv import load_dotenv

# %%
w3 = Web3(Web3.HTTPProvider("http://127.0.0.1:8545"))

# %%
w3.eth.blockNumber
# Out:
# 3683

# %%
w3.eth.getBalance("0xc60Fd985a61EbA9E3BA096F76F03e034975C6735")
# Out:
# 904625697166532776746648320380374280103671755200316906458261115061821325312

# %%
load_dotenv('/home/jwales/bootcamp/cryptostuff/JLW.env')
private_key = os.getenv("PRIVATE_KEY")

# %%
type(private_key)
# Out:
# str

# %%
"/home/jwales/bootcamp/cryptostuff/keystore"
