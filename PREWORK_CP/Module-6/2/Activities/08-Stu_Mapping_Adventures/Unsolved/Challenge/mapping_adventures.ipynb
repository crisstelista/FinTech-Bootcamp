# %% [markdown]
# # Mapping Adventures

# %% [markdown]
# It's time to plan an expedition for Harold's birthday! All he has told you so far is that he wants to go to NYC. Using the places of interest geospatial data, get a sense of the general location for places of interest. Use this as a guide for determining which boroughs/places you should hit for Harold's birthday adventure!

# %%
import pandas as pd
import plotly.express as px
import os
from pathlib import Path
from dotenv import load_dotenv

# %% [markdown]
# ### Prep Mapbox API Credentials

# %%
load_dotenv("../../../../../../.env")
# Set up API credentials
map_box_api = os.getenv("mapbox")
px.set_mapbox_access_token(map_box_api)

# %% [markdown]
# ### Read in data

# %%
# Read in data
places_of_interest = pd.read_csv(
    Path("../../Resources/nyc_places_interest.csv")
).dropna()
places_of_interest.head()
# Out:
#    Id  Longitude   Latitude                Name PlaceType Borough
# 0  90 -73.888958  40.896210  Van Cortlandt Park      Park   Bronx
# 1  95 -73.871651  40.889879   Woodlawn Cemetery  Cemetery   Bronx
# 2  81 -73.838642  40.886965    Seton Falls Park      Park   Bronx
# 3  69 -73.809802  40.877986     Pelham Bay Park      Park   Bronx
# 4   8 -73.878308  40.864424    Botanical Garden    Garden   Bronx

# %% [markdown]
# ### Plot Data

# %% [markdown]
# #### Plot All Places of Interest

# %%
# Slice and plot data by name
map_plot = px.scatter_mapbox(
    places_of_interest,
    lat="Latitude",
    lon="Longitude",
    size="Id",
    color="Name",
    zoom=4
)
map_plot.show()
# Out:
# <div>                            <div id="90de2861-6e4d-468d-b1d9-958906eeb596" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("90de2861-6e4d-468d-b1d9-958906eeb596")) {                    Plotly.newPlot(                        "90de2861-6e4d-468d-b1d9-958906eeb596",                        [{"hovertemplate": "Name=Van Cortlandt Park<br>Id=%{marker.size}<br>Latitude=%{lat}<br>Longitude=%{lon}<extra></extra>", "lat": [40.89620987], "legendgroup": "Van Cortlandt Park", "lon": [-73.88895812], "marker": {"color": "#636efa", "size": [90], "sizemode": "area", "sizeref": 0.24}, "mode": "markers", "name": "Van Cortlandt Park", "showlegend": true, "subplot": "mapbox", "type": "scattermapbox"}, {"hovertemplate": "Name=Woodlawn Cemetery<br>Id=%{marker.size}<br>Latitude=%{lat}<br>Longitude=%{lon}<extra></extra>", "lat": [40.88987947], "legendgroup": "Woodlawn Cemetery", "lon": [-73.87165103], "marker": {"color": "#EF553B", "size": [95], "sizemode": "area", "sizeref": 0.24}, "mode": "markers", "name": "Woodlawn Cemetery", "showlegend": true, "subplot": "mapbox", "type": "scattermapbox"}, {"hovertemplate": "Name=Seton Falls Park<br>Id=%{marker.size}<br>Latitude=%{lat}<br>Longitude=%{lon}<extra></extra>", "lat": [40.88696522], "legendgroup": "Seton Falls Park", "lon": [-73.83864189], "marker": {"color": "#00cc96", "size": [81], "sizemode": "area", "sizeref": 0.24}, "mode": "markers", "name": "Seton Falls Park", "showlegend": true, "subplot": "mapbox", "type": "scattermapbox"}, {"hovertemplate": "Name=Pelham Bay Park<br>Id=%{marker.size}<br>Latitude=%{lat}<br>Longitude=%{lon}<extra></extra>", "lat": [40.87798555], "legendgroup": "Pelham Bay Park", "lon": [-73.80980242], "marker": {"color": "#ab63fa", "size": [69], "sizemode": "area", "sizeref": 0.24}, "mode": "markers", "name": "Pelham Bay Park", "showlegend": true, "subplot": "mapbox", "type": "scattermapbox"}, {"hovertemplate": "Name=Botanical Garden<br>Id=%{marker.size}<br>Latitude=%{lat}<br>Longitude=%{lon}<extra></extra>", "lat": [40.86442395], "legendgroup": "Botanical Garden", "lon": [-73.87830776], "marker": {"color": "#FFA15A", "size": [8], "sizemode": "area", "sizeref": 0.24}, "mode": "markers", "name": "Botanical Garden", "showlegend": true, "subplot": "mapbox", "type": "scattermapbox"}, {"hovertemplate": "Name=Bronx Park<br>Id=%{marker.size}<br>Latitude=%{lat}<br>Longitude=%{lon}<extra></extra>", "lat": [40.85552207], "legendgroup": "Bronx Park", "lon": [-73.87626064], "marker": {"color": "#19d3f3", "size": [9], "sizemode": "area", "sizeref": 0.24}, "mode": "markers", "name": "Bronx Park", "showlegend": true, "subplot": "mapbox", "type": "scattermapbox"}, {"hovertemplate": "Name=Saint  Raymond's Cemetery<br>Id=%{marker.size}<br>Latitude=%{lat}<br>Longitude=%{lon}<extra></extra>", "lat": [40.82330815], "legendgroup": "Saint  Raymond's Cemetery", "lon": [-73.83530397], "marker": {"color": "#FF6692", "size": [78], "sizemode": "area", "sizeref": 0.24}, "mode": "markers", "name": "Saint  Raymond's Cemetery", "showlegend": true, "subplot": "mapbox", "type": "scattermapbox"}, {"hovertemplate": "Name=Ferry Point Park<br>Id=%{marker.size}<br>Latitude=%{lat}<br>Longitude=%{lon}<extra></extra>", "lat": [40.81434338], "legendgroup": "Ferry Point Park", "lon": [-73.8328464], "marker": {"color": "#B6E880", "size": [27], "sizemode": "area", "sizeref": 0.24}, "mode": "markers", "name": "Ferry Point Park", "showlegend": true, "subplot": "mapbox", "type": "scattermapbox"}, {"hovertemplate": "Name=Sound View Park<br>Id=%{marker.size}<br>Latitude=%{lat}<br>Longitude=%{lon}<extra></extra>", "lat": [40.8154443], "legendgroup": "Sound View Park", "lon": [-73.8721731], "marker": {"color": "#FF97FF", "size": [84], "sizemode": "area", "sizeref": 0.24}, "mode": "markers", " ...

# %% [markdown]
# #### Plot Places of Interest by Place Type

# %%
# Slice and plot data by place type
map_plot = px.scatter_mapbox(
    places_of_interest,
    lat="Latitude",
    lon="Longitude",
    size="Id",
    color="PlaceType",
    zoom=4
)
map_plot.show()
# Out:
# <div>                            <div id="24d46ae3-aefd-4a1b-ba2a-6d6e7e73e95a" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("24d46ae3-aefd-4a1b-ba2a-6d6e7e73e95a")) {                    Plotly.newPlot(                        "24d46ae3-aefd-4a1b-ba2a-6d6e7e73e95a",                        [{"hovertemplate": "PlaceType=Park<br>Id=%{marker.size}<br>Latitude=%{lat}<br>Longitude=%{lon}<extra></extra>", "lat": [40
park<br>Id=%{marker.size}<br>Latitude=%{lat}<br>Longitude=%{lon}<extra></extra>", "lat": [40.87798555], "legendgroup": "Pelham Bay Park", "lon": [-73.80980242], "marker": {"color": "#00cc96", "size": [69], "sizemode": "area", "sizeref": 0.24}, "mode": "markers", "name": "Pelham Bay Park", "showlegend": true, "subplot": "mapbox", "type": "scattermapbox"}, {"hovertemplate": "Name=Bronx Park<br>Id=%{marker.size}<br>Latitude=%{lat}<br>Longitude=%{lon}<extra></extra>", "lat": [40.85552207], "legendgroup": "Bronx Park", "lon": [-73.87626064], "marker": {"color": "#ab63fa", "size": [9], "sizemode": "area", "sizeref": 0.24}, "mode": "markers", "name": "Bronx Park", "showlegend": true, "subplot": "mapbox", "type": "scattermapbox"}, {"hovertemplate": "Name=Ferry Point Park<br>Id=%{marker.size}<br>Latitude=%{lat}<br>Longitude=%{lon}<extra></extra>", "lat": [40.81434338], "legendgroup": "Ferry Point Park", "lon": [-73.8328464], "marker": {"color": "#FFA15A", "size": [27], "sizemode": "area", "sizeref": 0.24}, "mode": "markers", "name": "Ferry Point Park", "showlegend": true, "subplot": "mapbox", "type": "scattermapbox"}, {"hovertemplate": "Name=Sound View Park<br>Id=%{marker.size}<br>Latitude=%{lat}<br>Longitude=%{lon}<extra></extra>", "lat": [40.8154443], "legendgroup": "Sound View Park", "lon": [-73.8721731], "marker": {"color": "#19d3f3", "size": [84], "sizemode": "area", "sizeref": 0.24}, "mode": "markers", "name": "Sound View Park", "showlegend": true, "subplot": "mapbox", "type": "scattermapbox"}, {"hovertemplate": "Name=Crotona Park<br>Id=%{marker.size}<br>Latitude=%{lat}<br>Longitude=%{lon}<extra></extra>", "lat": [40.8384766], "legendgroup": "Crotona Park", "lon": [-73.89422937], "marker": {"color": "#FF6692", "size": [21], "sizemode": "area", "sizeref": 0.24}, "mode": "markers", "name": "Crotona Park", "showlegend": true, "subplot": "mapbox", "type": "scattermapbox"}, {"hovertemplate": "Name=Zoo/Wildlife Conser. Park<br>Id=%{marker.size}<br>Latitude=%{lat}<br>Longitude=%{lon}<extra></extra>", "lat": [40.84900595], "legendgroup": "Zoo/Wildlife Conser. Park", "lon": [-73.87523757], "marker": {"color": "#B6E880", "size": [96], "sizemode": "area", "sizeref": 0.24}, "mode": "markers", "name": "Zoo/Wildlife Conser. Park", "showlegend": true, "subplot": "mapbox", "type": "scattermapbox"}, {"hovertemplate": "Name=Saint Mary's Park<br>Id=%{marker.size}<br>Latitude=%{lat}<br>Longitude=%{lon}<extra></extra>", "lat": [40.81147588], "legendgroup": "Saint Mary's Park", "lon": [-73.9117582], "marker": {"color": "#FF97FF", "size": [79], "sizemode": "area", "sizeref": 0.24}, "mode": "markers", "name": "Saint M ...

# %% [markdown]
# #### Plot Gardens of Interest

# %%
# Slice and plot data by place type of garden 
gardens = places_of_interest[places_of_interest['PlaceType']=='Garden']
map_plot = px.scatter_mapbox(
    gardens,
    lat="Latitude",
    lon="Longitude",
    size="Id",
    color="Name",
    zoom=4
)
map_plot.show()
# Out:
# <div>                            <div id="a2e1cc23-6a4c-44da-8695-9b4b5a07ddda" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("a2e1cc23-6a4c-44da-8695-9b4b5a07ddda")) {                    Plotly.newPlot(                        "a2e1cc23-6a4c-44da-8695-9b4b5a07ddda",                        [{"hovertemplate": "Name=Botanical Garden<br>Id=%{marker.size}<br>Latitude=%{lat}<br>Longitude=%{lon}<extra></extra>", "lat": [40.86442395], "legendgroup": "Botanical Garden", "lon": [-73.87830776], "marker": {"color": "#636efa", "size": [8], "sizemode": "area", "sizeref": 0.02}, "mode": "markers", "name": "Botanical Garden", "showlegend": true, "subplot": "mapbox", "type": "scattermapbox"}, {"hovertemplate": "Name=Botanic Garden<br>Id=%{marker.size}<br>Latitude=%{lat}<br>Longitude=%{lon}<extra></extra>", "lat": [40.66993701], "legendgroup": "Botanic Garden", "lon": [-73.96612486], "marker": {"color": "#EF553B", "size": [7], "sizemode": "area", "sizeref": 0.02}, "mode": "markers", "name": "Botanic Garden", "showlegend": true, "subplot": "mapbox", "type": "scattermapbox"}],                        {"legend": {"itemsizing": "constant", "title": {"text": "Name"}, "tracegroupgap": 0}, "mapbox": {"accesstoken": "pk.eyJ1IjoiY3Jpc3N0ZWxpc3RhIiwiYSI6ImNrbnFtd29jMjAxeGEyd3Jvazg4MGxuNHoifQ.VVzCX9n2WYUP1OsiwUK9qA", "center": {"lat": 40.76718048, "lon": -73.92221631}, "domain": {"x": [0.0, 1.0], "y": [0.0, 1.0]}, "zoom": 4}, "margin": {"t": 60}, "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, " ...

# %% [markdown]
# #### Plot Squares of Interest

# %%
# Slice and plot data by place type of square 
squares = places_of_interest[places_of_interest['PlaceType']=='Square']
map_plot = px.scatter_mapbox(
    squares,
    lat="Latitude",
    lon="Longitude",
    size="Id",
    color="Name",
    zoom=4
)
map_plot.show()
# Out:
# <div>                            <div id="56f0e763-8689-48dd-ad9d-12bbee288daa" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("56f0e763-8689-48dd-ad9d-12bbee288daa")) {                    Plotly.newPlot(                        "56f0e763-8689-48dd-ad9d-12bbee288daa",                        [{"hovertemplate": "Name=Times Square<br>Id=%{marker.size}<br>Latitude=%{lat}<br>Longitude=%{lon}<extra></extra>", "lat": [40.7580213], "legendgroup": "Times Square", "lon": [-73.98179379], "marker": {"color": "#636efa", "size": [88], "sizemode": "area", "sizeref": 0.2225}, "mode": "markers", "name": "Times Square", "showlegend": true, "subplot": "mapbox", "type": "scattermapbox"}, {"hovertemplate": "Name=Madison Square<br>Id=%{marker.size}<br>Latitude=%{lat}<br>Longitude=%{lon}<extra></extra>", "lat": [40.7421814], "legendgroup": "Madison Square", "lon": [-73.98806663], "marker": {"color": "#EF553B", "size": [56], "sizemode": "area", "sizeref": 0.2225}, "mode": "markers", "name": "Madison Square", "showlegend": true, "subplot": "mapbox", "type": "scattermapbox"}, {"hovertemplate": "Name=Union Square<br>Id=%{marker.size}<br>Latitude=%{lat}<br>Longitude=%{lon}<extra></extra>", "lat": [40.73595972], "legendgroup": "Union Square", "lon": [-73.9903801], "marker": {"color": "#00cc96", "size": [89], "sizemode": "area", "sizeref": 0.2225}, "mode": "markers", "name": "Union Square", "showlegend": true, "subplot": "mapbox", "type": "scattermapbox"}],                        {"legend": {"itemsizing": "constant", "title": {"text": "Name"}, "tracegroupgap": 0}, "mapbox": {"accesstoken": "pk.eyJ1IjoiY3Jpc3N0ZWxpc3RhIiwiYSI6ImNrbnFtd29jMjAxeGEyd3Jvazg4MGxuNHoifQ.VVzCX9n2WYUP1OsiwUK9qA", "center": {"lat": 40.74538747333333, "lon": -73.98674684000001}, "domain": {"x": [0.0, 1.0], "y": [0.0, 1.0]}, "zoom": 4}, "margin": {"t": 60}, "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatm ...
